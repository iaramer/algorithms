# %% [markdown]
# # **Colors**
#
# Colors are often represented in computers as vectors with three dimensions:  *Red*, *Green*, and *Blue* (RGB). In other words, a color is expressed as an RGB triplet $(r,g,b)$, each component of which can vary from zero to a defined maximum value:
#
# ![rgb slider](https://upload.wikimedia.org/wikipedia/en/1/12/RGB_sliders.svg)
#
# If all the components are at zero the result is black. If, by contrast, all are at maximum, the result is the brightest representable white.
#
#
# In this notebook, you will practice basic vector operations with color vectors from an [xkcd color survey](https://blog.xkcd.com/2010/05/03/color-survey-results/).

# %% [markdown]
# ## **Loading the data**
#
# First, we'll load the original JSON-file into a Python dictionary.

# %%
import requests, json

url = 'https://raw.githubusercontent.com/evgeniyako-edu/corpora/master/data/colors/xkcd.json'
response = requests.get(url)

raw_data = json.loads(response.text)

# %% [markdown]
# Take a look at the content of $\texttt{raw_data}$.

# %%
raw_data
# Out:
# {'colors': [{'color': 'cloudy blue', 'hex': '#acc2d9'},
#   {'color': 'dark pastel green', 'hex': '#56ae57'},
#   {'color': 'dust', 'hex': '#b2996e'},
#   {'color': 'electric lime', 'hex': '#a8ff04'},
#   {'color': 'fresh green', 'hex': '#69d84f'},
#   {'color': 'light eggplant', 'hex': '#894585'},
#   {'color': 'nasty green', 'hex': '#70b23f'},
#   {'color': 'really light blue', 'hex': '#d4ffff'},
#   {'color': 'tea', 'hex': '#65ab7c'},
#   {'color': 'warm purple', 'hex': '#952e8f'},
#   {'color': 'yellowish tan', 'hex': '#fcfc81'},
#   {'color': 'cement', 'hex': '#a5a391'},
#   {'color': 'dark grass green', 'hex': '#388004'},
#   {'color': 'dusty teal', 'hex': '#4c9085'},
#   {'color': 'grey teal', 'hex': '#5e9b8a'},
#   {'color': 'macaroni and cheese', 'hex': '#efb435'},
#   {'color': 'pinkish tan', 'hex': '#d99b82'},
#   {'color': 'spruce', 'hex': '#0a5f38'},
#   {'color': 'strong blue', 'hex': '#0c06f7'},
#   {'color': 'toxic green', 'hex': '#61de2a'},
# ...

# %% [markdown]
# You can notice that the original format is not very convenient to use. Let's convert hex color values into RGB-triplets and create a new dictionary {$\texttt{"color_name": [r, g, b]}$}.
#
# Run the cells below to do so.

# %%
def hex_to_rgb(color_hex):
    color_hex = color_hex.lstrip("#")
    return [int(color_hex[:2], 16), int(color_hex[2:4], 16), int(color_hex[4:6], 16)]

# %%
colors = dict()

for item in raw_data['colors']:
    colors[item['color']] = hex_to_rgb(item['hex'])

# %%
colors
# Out:
# {'acid green': [143, 254, 9],
#  'adobe': [189, 108, 72],
#  'algae': [84, 172, 104],
#  'algae green': [33, 195, 111],
#  'almost black': [7, 13, 13],
#  'amber': [254, 179, 8],
#  'amethyst': [155, 95, 192],
#  'apple': [110, 203, 60],
#  'apple green': [118, 205, 38],
#  'apricot': [255, 177, 109],
#  'aqua': [19, 234, 201],
#  'aqua blue': [2, 216, 233],
#  'aqua green': [18, 225, 147],
#  'aqua marine': [46, 232, 187],
#  'aquamarine': [4, 216, 178],
#  'army green': [75, 93, 22],
#  'asparagus': [119, 171, 86],
#  'aubergine': [61, 7, 52],
#  'auburn': [154, 48, 1],
#  'avocado': [144, 177, 52],
#  'avocado green': [135, 169, 34],
#  'azul': [29, 93, 236],
#  'azure': [6, 154, 243],
#  'baby blue': [162, 207, 254],
#  'baby green': [140, 255, 158],
#  'baby pink': [255, 183, 206],
#  'baby poo': [171, 144, 4],
#  'baby poop': [147, 124, 0],
#  'baby poop green': [143, 152, 5],
#  'baby puke green': [182, 196, 6],
#  'baby purple': [202, 155, 247],
# ...

# %%
import pandas as pd
df = pd.DataFrame(colors)
df = df.T
df = df.reset_index()

# %%
df
# Out:
#                  index    0    1    2
# 0          cloudy blue  172  194  217
# 1    dark pastel green   86  174   87
# 2                 dust  178  153  110
# 3        electric lime  168  255    4
# 4          fresh green  105  216   79
# ..                 ...  ...  ...  ...
# 944              brown  101   55    0
# 945               pink  255  129  192
# 946               blue    3   67  223
# 947              green   21  176   26
# 948             purple  126   30  156
#
# [949 rows x 4 columns]

# %% [markdown]
# Take a look at the content of the $\texttt{colors}$ dictionary now.

# %% [markdown]
# ## **Plotting the data**
#
# To have a better idea of which colors are present in our dataset, let's plot them as points in a 3D space (with Red, Green and Blue as axes).
#
# Assign each point a color that it represents.
#
# Hint 1: [$\texttt{scatter3D}$](https://matplotlib.org/stable/gallery/mplot3d/scatter3d.html) function from the $\texttt{matplotlib}$ library might be useful for plotting points in 3D.
#
# Hint 2: In $\texttt{matplotlib}$, you can specify color by giving it's name from the xkcd survey with an $\texttt{'xkcd:'}$ prefix. See [documentation](https://matplotlib.org/3.1.0/tutorials/colors/colors.html) for more info.

# %%
cc = [v['hex'] for v in raw_data['colors']]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Your code here

# %%
list(df['index'])
# Out:
# ['cloudy blue',
#  'dark pastel green',
#  'dust',
#  'electric lime',
#  'fresh green',
#  'light eggplant',
#  'nasty green',
#  'really light blue',
#  'tea',
#  'warm purple',
#  'yellowish tan',
#  'cement',
#  'dark grass green',
#  'dusty teal',
#  'grey teal',
#  'macaroni and cheese',
#  'pinkish tan',
#  'spruce',
#  'strong blue',
#  'toxic green',
#  'windows blue',
#  'blue blue',
#  'blue with a hint of purple',
#  'booger',
#  'bright sea green',
#  'dark green blue',
#  'deep turquoise',
#  'green teal',
#  'strong pink',
#  'bland',
#  'deep aqua',
#  'lavender pink',
#  'light moss green',
#  'light seafoam green',
#  'olive yellow',
#  'pig pink',
#  'deep lilac',
#  'desert',
#  'dusty lavender',
#  'purpley grey',
#  'purply',
#  'candy pink',
#  'light pastel green',
#  'boring green',
#  'kiwi green',
#  'light grey green',
#  'orange pink',
#  'tea green',
#  'very light brown',
#  'egg shell',
#  'eggplant purple',
#  'powder pink',
#  'reddish grey',
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# for (c, rgb) in colors.items():
  # ax.scatter(rgb[0], rgb[1], rgb[2])

ax.scatter(df[0], df[1], df[2], c=cc)

# %% [markdown]
# Take a look at the plot you've obtained. Where are 'redish', 'greenish' and 'blueish' colors located? What can you say about the location of similar colors?

# %% [markdown]
# ## **Distances between colors**
#
# Recall that Euclidian distance between two points $x=(x_1, ..., x_n)$ and $y = (y_1, ..., y_n)$ in an $n$-dimensional space is defined as follows:
#
# $dist(x, y) = ||x-y||_2 = \sqrt{(x_1-y_1)^2 + ... + (x_n-y_n)^2}$.
#
# Implement a function that computed Euclidian distance between two colors in the RGB-space.

# %%
import numpy as np
np.array(df[df['index']== 'red'][[0,1,2]])
# Out:
# array([[229,   0,   0]])

# %%
import numpy as np

def distance(color1, color2):
  # c1 = np.array(df[df['index'] == color1][[0,1,2]])
  # c2 = np.array(df[df['index'] == color2][[0,1,2]])
  c1 = np.array(color1)
  c2 = np.array(color2)
  return np.sqrt(np.sum((c1 - c2) ** 2))

# %% [markdown]
# Try to use your function for computing distances between different colors in the data. What do you observe?

# %%
distance(colors['red'], colors['dark red'])
# Out:
# 97.0

# %%
distance(colors['red'], colors['blue'])
# Out:
# 324.49036965678965

# %% [markdown]
# Now, implement a function that, given some RGB-vector, returns $n$ closest colors from our $\texttt{colors}$ dictionary.

# %%
colors
# Out:
# {'acid green': [143, 254, 9],
#  'adobe': [189, 108, 72],
#  'algae': [84, 172, 104],
#  'algae green': [33, 195, 111],
#  'almost black': [7, 13, 13],
#  'amber': [254, 179, 8],
#  'amethyst': [155, 95, 192],
#  'apple': [110, 203, 60],
#  'apple green': [118, 205, 38],
#  'apricot': [255, 177, 109],
#  'aqua': [19, 234, 201],
#  'aqua blue': [2, 216, 233],
#  'aqua green': [18, 225, 147],
#  'aqua marine': [46, 232, 187],
#  'aquamarine': [4, 216, 178],
#  'army green': [75, 93, 22],
#  'asparagus': [119, 171, 86],
#  'aubergine': [61, 7, 52],
#  'auburn': [154, 48, 1],
#  'avocado': [144, 177, 52],
#  'avocado green': [135, 169, 34],
#  'azul': [29, 93, 236],
#  'azure': [6, 154, 243],
#  'baby blue': [162, 207, 254],
#  'baby green': [140, 255, 158],
#  'baby pink': [255, 183, 206],
#  'baby poo': [171, 144, 4],
#  'baby poop': [147, 124, 0],
#  'baby poop green': [143, 152, 5],
#  'baby puke green': [182, 196, 6],
#  'baby purple': [202, 155, 247],
# ...

# %%
def find_n_closest(colors, new_color, n=5):
  d = dict()
  for c, rgb in colors.items():
    d[c] = distance(rgb, new_color)
  ans = dict()
  for k,v in dict(sorted(d.items(), key=lambda item: item[1])).items():
    if n == 0:
      break
    ans[k] = v
    n -= 1
  return ans

# %% [markdown]
# Now, let's take some random new color and find $n=10$ closest colors to it in our dictionary.
#
# Experiment with different colors!

# %%
n = 10
new_color = [152, 70, 10]

# Your code here
# closest = ...

closest = find_n_closest(colors, new_color, n=10)

# %%
closest
# Out:
# {'auburn': 23.853720883753127,
#  'brown red': 28.106938645110393,
#  'burnt sienna': 25.787593916455254,
#  'burnt umber': 9.0,
#  'cinnamon': 22.293496809607955,
#  'raw umber': 28.319604517012593,
#  'russet': 16.583123951777,
#  'rust': 18.894443627691185,
#  'rust brown': 25.67099530598687,
#  'warm brown': 11.489125293076057}

# %% [markdown]
# ## **Operations with color vectors**
#
# Let's now try to perform some vector operations on the RGB-vectors.
#
# ### Vector addition
#
# Define a function that sums up to vectors.

# %%
def add_colors(color1, color2):
  return np.array(color1) + np.array(color2)

# %% [markdown]
# Let's consider two colors, for example $\texttt{red}$ and $\texttt{blue}$:

# %%
color1 = 'red'
color2 = 'blue'

# Plotting the colors 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4, 2))
ax1.set_facecolor('xkcd:'+color1) 
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title(color1)

ax2.set_facecolor('xkcd:'+color2) 
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_title(color2)
# Out:
# Text(0.5, 1.0, 'blue')

# %% [markdown]
# Which colors in our dictionary are the closest to the sum of those two colors?

# %%
find_n_closest(colors, add_colors(colors['red'], colors['blue']))
# Out:
# {'heliotrope': 29.206163733020468,
#  'pink purple': 16.06237840420901,
#  'pinkish purple': 20.322401432901575,
#  'purple pink': 11.357816691600547,
#  'purpleish pink': 27.03701166919155}

# %%
color1 = 'heliotrope'
color2 = 'pink purple'
color3 = 'pinkish purple'
color4 = 'purple pink'
color5 = 'purpleish pink'

# Plotting the colors
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(10, 2))
ax1.set_facecolor('xkcd:'+color1) 
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title(color1)

ax2.set_facecolor('xkcd:'+color2) 
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_title(color2)

ax3.set_facecolor('xkcd:'+color3) 
ax3.set_xticks([])
ax3.set_yticks([])
ax3.set_title(color3)

ax4.set_facecolor('xkcd:'+color3) 
ax4.set_xticks([])
ax4.set_yticks([])
ax4.set_title(color2)

ax5.set_facecolor('xkcd:'+color3) 
ax5.set_xticks([])
ax5.set_yticks([])
ax5.set_title(color2)
# Out:
# Text(0.5, 1.0, 'pink purple')

# %% [markdown]
# Experiment with more colors!

# %% [markdown]
# ### Vector subtraction
#
# Define a function that subtracts one vector from the other.

# %%
def subtract_colors(color1, color2):
  return np.array(color1) - np.array(color2)

# %% [markdown]
# Now, let's consider $\texttt{purple}$ and $\texttt{red}$:

# %%
color1 = 'purple'
color2 = 'red'

# Plotting the colors
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(4, 2))
ax1.set_facecolor('xkcd:'+color1) 
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title(color1)

ax2.set_facecolor('xkcd:'+color2) 
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_title(color2)
# Out:
# Text(0.5, 1.0, 'red')

# %% [markdown]
# What does the difference between them looks like? Find the closest colors n our dictionary.

# %%
find_n_closest(colors, subtract_colors(colors['red'], colors['purple']))
# Out:
# {'blood': 160.63934760823702,
#  'dark red': 161.48374531202822,
#  'deep brown': 163.7192719260625,
#  'dried blood': 162.46230331987786,
#  'mahogany': 161.67250848551834}

# %%
color1 = 'blood'
color2 = 'dark red'
color3 = 'deep brown'
color4 = 'dried blood'
color5 = 'mahogany'

# Plotting the colors
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(1, 5, figsize=(10, 2))
ax1.set_facecolor('xkcd:'+color1) 
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_title(color1)

ax2.set_facecolor('xkcd:'+color2) 
ax2.set_xticks([])
ax2.set_yticks([])
ax2.set_title(color2)

ax3.set_facecolor('xkcd:'+color3) 
ax3.set_xticks([])
ax3.set_yticks([])
ax3.set_title(color3)

ax4.set_facecolor('xkcd:'+color3) 
ax4.set_xticks([])
ax4.set_yticks([])
ax4.set_title(color2)

ax5.set_facecolor('xkcd:'+color3) 
ax5.set_xticks([])
ax5.set_yticks([])
ax5.set_title(color2)
# Out:
# Text(0.5, 1.0, 'dark red')

# %% [markdown]
# ## **References**
#
# This notebook is inspired by a [tutorial by Allison Parrish](https://gist.github.com/aparrish/2f562e3737544cf29aaf1af30362f469).

# %%
import numpy as np

def distance(v1, v2):
  c1 = np.array(v1)
  c2 = np.array(v2)
  return np.sqrt(np.sum((c1 - c2) ** 2))

# %%
x1 = [4, 3, 6]
x2 = [3, 1, 9]
x3 = [1, 4, 10]
x4 = [3, 4, 0]

# %%
a = [3, 1, 4]

# %%
distance(a, x1)
# Out:
# 3.0

# %%
distance(a, x2)
# Out:
# 5.0

# %%
distance(a, x3)
# Out:
# 7.0

# %%
distance(a, x4)
# Out:
# 5.0

# %%
x1 = [4, 3, 6]
x2 = [3, 1, 9]
x3 = [1, 4, 10]
x4 = [3, 4, 0]

# %%
a = [3, 1, 4]

# %%
def length(v):
  return np.sqrt(np.dot(v, v))

def angle(v1, v2):
  v1 = np.array(v1)
  v2 = np.array(v2)
  return np.arccos(np.dot(v1, v2) / (length(v1) * length(v2)))

# %%
angle(a, x1)
# Out:
# 0.20385304008024746

# %%
angle(a, x2)
# Out:
# 0.3310744631025462

# %%
angle(a, x3)
# Out:
# 0.5507078467717531

# %%
angle(a, x4)
# Out:
# 1.0357255195997424

# %%
angle([1,0], [-1,0])
# Out:
# 3.141592653589793
